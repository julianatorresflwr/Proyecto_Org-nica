# %% [markdown]
# <a href="https://colab.research.google.com/github/julianatorresflwr/Proyecto_Org-nica/blob/main/Proyecto_qu%C3%ADmica_org%C3%A1nica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar Librerias

# %%
import pandas as pd
import numpy as np
#import ploty as pt
